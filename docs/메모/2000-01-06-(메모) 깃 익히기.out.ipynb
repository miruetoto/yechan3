# %% [markdown]
# # (메모) – 깃 익히기
#
# 신록예찬
# 2000-01-06
#
# # clone
#
# github repository $\to$ code $\to$ clone tab, ssh를 복사
# (`git@github.com:miruetoto/yechan.git`처럼 생김)
#
# 터미널에서 아래를 입력
#
# ``` default
# git clone git@github.com:miruetoto/yechan.git 01_yechan
# ```
#
# # pull
#
# `-` 깃이 설치된 가장 상위폴더(Documents/Github/miruetoto.github.io)에
# 가서 아래를 입력한다.
#
# ``` default
# git pull
# ```
#
# # branch
#
# `-` 서버에 이미 guebin이라는 브랜치가 있다면 아래와 같이 동기화 시킨다.
#
# ``` default
# git chechout guebin
# git push -u origin guebin
# ```
#
# 여기에서 `git push -u origin guebin`을 안해도 동기화가 잘될때도 있는데
# 아닐때도 있다.
#
# # remote
#
# `-` 깃이 설치된 가장 상위폴더(Documents/Github/miruetoto.github.io)에
# 가서 아래를 입력하면 깃허브의 url 주소를 확인할 수 있다.
#
# ``` default
# (base) lgcgb2@lgcgb2:~/Documents/GitHub/miruetoto.github.io$ git remote -v
# origin https://github.com/miruetoto/miruetoto.github.io.git (fetch)
# origin https://github.com/miruetoto/miruetoto.github.io.git (push)
# upstream https://github.com/daattali/beautiful-jekyll.git (fetch)
# upstream https://github.com/daattali/beautiful-jekyll.git (push)
# ```
#
# # config
#
# `-` 설정보기
#
# ``` default
# git config —list
# ```
#
# `-` 설정삭제
#
# ``` default
# git config --unset user.name
# git config --unser user.email
# ```
#
# `-` 전역설정삭제
#
# ``` default
# git config --unset --global user.name
# git config --unset --global user.email
# ```
#
# `-` 중복값 설정삭제
#
# ``` default
# git config --unset-all user.name
# git config --unset-all user.email
# ```
#
# `-` 중복값 전역으로 설정삭제
#
# ``` default
# git config --unset-all --global user.name
# git config --unset-all --global user.email
# ```
#
# `-` 비번안치고 푸쉬하는법?
#
# ``` default
# git config credential.helper store
# ```
#
# 입력이후에 `git push`
#
# # Git token
#
# <https://github.com/settings/tokens> 에서 확인가능
#
# ### Appendix
#
# #### 리눅스에서 github desktop 설치
#
# -   [여기](https://github.com/shiftkey/desktop/releases)로 간다.
# -   한 챕터의 (2.3.1 Linux RC1 와 같이 되어있음) 아래쪽에 보면 **▶
#     Assets** 라고 되어있는데 이걸 클릭하면 다운받을 수 있는 파일들이
#     나온다. 확장자가 .deb로 끝나는걸 골라서 다운받은뒤에 실행한다.
