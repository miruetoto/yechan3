# %% [markdown]
# # (연구) graft – tutorial
#
# 신록예찬
# 2023-11-09
#
# # 1. Install
#
# ``` bash
# conda create -n graft
# conda activate graft
# conda install pytorch torchvision torchaudio pytorch-cuda=12.1 -c pytorch -c nvidia
# conda install pyg -c pyg
# conda install -c conda-forge notebook
# conda install pyg -c pyg
# conda install -c conda-forge graph-tool
# ```
#
# ref:
# <https://git.skewed.de/count0/graph-tool/-/wikis/installation-instructions>

# %%
# !pip uninstall graft -y
# !pip install git+https://github.com/guebin/graft.git
# Out:
# Found existing installation: graft 0.0.1
# Uninstalling graft-0.0.1:
#   Successfully uninstalled graft-0.0.1
# Collecting git+https://github.com/guebin/graft.git
#   Cloning https://github.com/guebin/graft.git to /tmp/pip-req-build-66n018dl
#   Running command git clone --filter=blob:none --quiet https://github.com/guebin/graft.git /tmp/pip-req-build-66n018dl
#   Resolved https://github.com/guebin/graft.git to commit e5f7aba84ad29a030c538d96dfb79dd33d3c0d20
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: pandas in /home/cgb3/anaconda3/envs/graft/lib/python3.12/site-packages (from graft==0.0.1) (2.2.1)
# Requirement already satisfied: numpy<2,>=1.26.0 in /home/cgb3/anaconda3/envs/graft/lib/python3.12/site-packages (from pandas->graft==0.0.1) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/cgb3/anaconda3/envs/graft/lib/python3.12/site-packages (from pandas->graft==0.0.1) (2.9.0)
# Requirement already satisfied: pytz>=2020.1 in /home/cgb3/anaconda3/envs/graft/lib/python3.12/site-packages (from pandas->graft==0.0.1) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /home/cgb3/anaconda3/envs/graft/lib/python3.12/site-packages (from pandas->graft==0.0.1) (2024.1)
# Requirement already satisfied: six>=1.5 in /home/cgb3/anaconda3/envs/graft/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas->graft==0.0.1) (1.16.0)
# Building wheels for collected packages: graft
#   Building wheel for graft (setup.py) ... done
#   Created wheel for graft: filename=graft-0.0.1-py3-none-any.whl size=7875 sha256=21c972f6e03480aad89475587d730078fa30e77239b447d0cdd85a46c24410f8
#   Stored in directory: /tmp/pip-ephem-wheel-cache-_fmns6qf/wheels/5a/da/81/7f1de9f08d7753f35b8a3ca78aaacecedc86bc4077124d73fe
# Successfully built graft
# Installing collected packages: graft
# Successfully installed graft-0.0.1

# %% [markdown]
# # 2. Imports

# %%
import numpy as np
import torch
import torch_geometric
import graft
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # 3. Undirected / Unweighted
#
# `# Ex` – default

# %%
links = torch.tensor([[0, 1, 2, 3, 4, 3],
                      [1, 0, 3, 2, 3, 4]], dtype=torch.long)
g = torch_geometric.data.Data(
    edge_index = links
)

# %%
graft.graph.plot_undirected_unweighted(g)

# %% [markdown]
# `# Ex` – node_names

# %%
graft.graph.plot_undirected_unweighted(
    g, 
    node_names = ['a','b','c','d','e'], 
)

# %% [markdown]
# `# Ex` – node_color (continuous)

# %%
links = torch.tensor([[0, 1, 2, 3, 4, 3],
                      [1, 0, 3, 2, 3, 4]], dtype=torch.long)
g = torch_geometric.data.Data(
    edge_index = links, 
    y = np.random.randn(5)
)

# %%
graft.graph.plot_undirected_unweighted(
    g,
    node_color=g.y
)

# %% [markdown]
# `# Ex` – node_color (discrete)

# %%
links = torch.tensor([[0, 1, 2, 3, 4, 3],
                      [1, 0, 3, 2, 3, 4]], dtype=torch.long)
g = torch_geometric.data.Data(
    edge_index = links, 
    y = torch.tensor([0,1,0,0,1])
)

# %%
graft.graph.plot_undirected_unweighted(
    g,
    node_color=g.y
)

# %% [markdown]
# `# Ex` – node_color (discrete) / node_size

# %%
links = torch.tensor([[0, 1, 2, 3, 4, 3],
                      [1, 0, 3, 2, 3, 4]], dtype=torch.long)
g = torch_geometric.data.Data(
    edge_index = links, 
    y = torch.tensor([0,1,0,0,1]),
    x = torch.tensor([10,100,15,20,150])
)

# %%
graft.graph.plot_undirected_unweighted(
    g,
    node_color=g.y,
    node_size=g.x
)

# %% [markdown]
# `# Ex` – draw options

# %%
links = torch.tensor([[0, 1, 2, 3, 4, 3],
                      [1, 0, 3, 2, 3, 4]], dtype=torch.long)
g = torch_geometric.data.Data(
    edge_index = links
)

# %%
graft.graph.plot_undirected_unweighted(
    g,
)

# %%
dr_opts = {
    'vertex_size':30
}
graft.graph.plot_undirected_unweighted(
    g,
    draw_options= dr_opts
)

# %%
dr_opts = {
    'edge_marker_size': 200, 
    'output_size': (300,300)
}
graft.graph.plot_undirected_unweighted(
    g,
    draw_options= dr_opts
)

# %% [markdown]
# # 4. Undirected / Weighted
#
# `# Ex`

# %%
links = torch.tensor([[0, 1, 2, 3, 4, 3],
                      [1, 0, 3, 2, 3, 4]], dtype=torch.long)
weights = torch.tensor([5, 5, 1.5, 1.5, 0.19, 0.19], dtype=torch.float)

g = torch_geometric.data.Data(
    edge_index=links,
    edge_attr=weights,
)

# %%
graft.graph.plot_undirected_weighted(
    g,
)

# %% [markdown]
# `# Ex`

# %%
links = torch.tensor([[0, 1, 2, 3, 4, 3],
                      [1, 0, 3, 2, 3, 4]], dtype=torch.long)
weights = torch.tensor([5, 5, 1.5, 1.5, 0.19, 0.19], dtype=torch.float)

g = torch_geometric.data.Data(
    edge_index=links,
    edge_attr=weights,
)

# %%
graft.graph.plot_undirected_weighted(
    g,
    edge_weight_text=False
)

# %%
graft.graph.plot_undirected_weighted(
    g,
    edge_weight_text=False,
    edge_weight_width=False
)

# %%
graft.graph.plot_undirected_weighted(
    g,
    edge_weight_text=True,
    edge_weight_width=True,
    edge_weight_text_format='.1f',
)

# %%
graft.graph.plot_undirected_weighted(
    g,
    edge_weight_text=True,
    edge_weight_width=True,
    edge_weight_text_format='.1f',
    edge_weight_width_scale=5.0,
)

# %% [markdown]
# `# Ex`

# %%
links = torch.tensor([[0, 1, 2, 3, 4, 3],
                      [1, 0, 3, 2, 3, 4]], dtype=torch.long)
weights = torch.tensor([5, 5, 1.5, 1.5, 0.19, 0.19], dtype=torch.float)

g = torch_geometric.data.Data(
    edge_index=links,
    edge_attr=weights,
    y = torch.tensor([1,1,0,0,0])
)

# %%
graft.graph.plot_undirected_weighted(
    g,
    node_color=g.y
)

# %% [markdown]
# `# Ex`

# %%
links = torch.tensor([[0, 1, 2, 3, 4, 3],
                      [1, 0, 3, 2, 3, 4]], dtype=torch.long)
weights = torch.tensor([5, 5, 1.5, 1.5, 0.19, 0.19], dtype=torch.float)
g = torch_geometric.data.Data(
    edge_index = links, 
    edge_attr = weights,
    y = torch.tensor([0,1,0,0,1]),
    x = torch.tensor([1,3,1,2,4])
)

# %%
graft.graph.plot_undirected_weighted(
    g,
    node_color=g.y,
    node_size=g.x,
    edge_weight_text=False,
)
