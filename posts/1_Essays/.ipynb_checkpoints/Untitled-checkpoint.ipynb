# %% [raw]
# ---
# title: "**[Essays]** EPT, dissimilarity"
# author: "신록예찬"
# date: "08/08/2023"
# ---

# %% [markdown]
# # simulation

# %%
library(EPT)

# %%
t = 0:1000/100
y = sin(t)

# %%
plot(t,y,type='l')
# Out:
# plot without title
