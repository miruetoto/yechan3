# %% [raw]
# ---
# title: "[CGSP] Weakly Stationary Graph Processes"
# author: "신록예찬"
# date: "12/26/2022"
# bibliography: cgsp.bib
# ---

# %% [markdown]
# # Preliminary Study

# %% [markdown]
# ## Simultaneously Diagonalizable

# %% [markdown]
# A set of matrices is said to be simultaneously diagonalizable if there exists a single inverible matrix ${\bf V}$ such that
#
# $${\bf V}^{-1}{\bf A}{\bf V}$$
#
# is a diagonal matrix for every ${\bf A}$ in the set.

# %% [markdown]
# ![image.png](attachment:1022c289-8755-4c5c-b3f5-24cba40e1702.png)

# %% [markdown]
# # Weakly Stationary Graph Processes

# %% [markdown]
# **Definition.** Given a normal shift operator ${\bf S}$, a zero-mean random process ${\bf x}$ is weakly stationary with respect to ${\bf S}$ if it can be written as the response of a linear shift-invariant graph filter ${\bf H}=\sum_{l=0}^{N-1}h_l{\bf S}^l$ to a zero-mean white input ${\bf n}$.

# %% [markdown]
# **Definition.** Given a normal shift operator ${\bf S}$, a zero-mean random process ${\bf x}$ is weakly stationary with respect to ${\bf S}$ is the following two equivalent properties hold
#
# **(a)** For any set of nonnegative integers $a$,$b$, and $c\leq b$ it holds that
#
# $$ \mathbb{E} \bigg[ \big({\bf S}^a{\bf x}\big)\Big(\big({\bf S}^H)^b {\bf x}\Big)^H  \bigg]=\mathbb{E}\bigg[\big({\bf S}^{a+c}{\bf x}\big)\Big(\big({\bf S}^H\big)^{b-c}{\bf x} \Big)^H \bigg] $$

# %% [markdown]
# **(b)** Matrices ${\bf C}_{\bf x}$ and ${\bf S}$ are simultaneously diagonalizable.^[Here ]

# %% [markdown]
# ---

# %% [markdown]
# ---
