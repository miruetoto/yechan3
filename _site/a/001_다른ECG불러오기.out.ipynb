# %% [markdown]
# #

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
fnames = ['/home/cgb2/Dropbox/03_yechan3/_/118e00.csv',
'/home/cgb2/Dropbox/03_yechan3/_/118e06.csv',
'/home/cgb2/Dropbox/03_yechan3/_/118e12.csv',
'/home/cgb2/Dropbox/03_yechan3/_/118e24.csv',
'/home/cgb2/Dropbox/03_yechan3/_/e0103.csv',
'/home/cgb2/Dropbox/03_yechan3/_/e0110.csv',
'/home/cgb2/Dropbox/03_yechan3/_/e0124.csv']

# %%
titles = [f.split('/')[-1] for f in fnames]
titles

# %%
fig,axs = plt.subplots(len(fnames))
fig.set_size_inches(10,20)
for i in range(len(fnames)):
    signal = pd.read_csv(fnames[i],header=None)
    axs[i].plot(signal[:5000])
    axs[i].set_title(titles[i])
