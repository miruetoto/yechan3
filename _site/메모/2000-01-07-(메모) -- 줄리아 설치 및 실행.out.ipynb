# %% [markdown]
# # (메모) – 줄리아 설치 및 실행
#
# 신록예찬
# 2000-01-07
#
# # 설치
#
# `-` [여기](https://julialang.org/downloads/)에 접속한다. 스크롤링하여
# ’Generic Linux Binaries for x86 / 64-bit(GPG)’를 찾는다. 그리고
# ’64-bit’를 클릭해서 다운받는다. (참고로 왼쪽에 ’help’를 누르면
# 설치페이지 설명서가 나온다.) 그러면 아래와 같은 파일이 나온다.
#
# ``` default
# julia-1.3.1-linux-x86_64.tar.gz
# ```
#
# 이 파일을 더블클릭해서 압축을 풀어준다. 압축을 풀면 `julia-1.3.1`라는
# 폴더가 생긴다. 이 폴더를 원하는 위치로 (줄리아가 설치되기를 원하는 위치)
# 이동시킨다. 나는 home에 이동시켰다.
#
# `-` 아래를 실행하면 줄리아가 실행된다. (둘중 아무거나)
#
# ``` default
# /home/cgb/julia-1.3.1/bin/julia
# ~/julia-1.3.1/bin/julia
# ```
#
# # 주피터와 연결
#
# `-` 아래중 하나를 실행하여 줄리아를 킨다.
#
# ``` default
# /home/cgb/julia-1.3.1/bin/julia
# ~/julia-1.3.1/bin/julia
# ```
#
# `-` 줄리아를 실행한뒤에 아래를 입력하면 주피터노트북에 연결된다.
#
# ``` default
# using Pkg
# Pkg.add("IJulia")
# ```
#
# `-` 한 가지 의문점이 있다. 나같은 경우는 ’(base)’에서 줄리아를 실행하고
# 연결하였다. 그런데 혹시 몰라서 `(py38r40)`에서도 줄리아를 실행해봤는데
# 잘 실행되었다. 줄리아를 실행시키고 위의 명령 `Pkg.add("IJulia")`를
# 다시쳤는데, 이미 연결되어서 더이상 변화시킨게 없다는 메시지가 떴다.
# 이러면 `(base)`에 설치된 줄리아가 `(py38r40)`에서도 실행된 줄리아와
# 동일하다는 의미일까? $\Longrightarrow$ 그렇다. 왜냐하면 줄리아는
# anaconda내의 폴더에 설치한 것이 아니기 때문에. home에 보통 설치하니깐.
#
# # 환경변수 조정
#
# `-` 참고로 어디서든 줄리아를 실행시키고 싶다면 환경변수를 조작하면 된다.
# 아래를 실행해서 나노에디터를 킨다.
#
# ``` default
# sudo nano /etc/environment
# ```
#
# 맨끝에 다음과 같이 되어있을 것이다.
#
# ``` default
# ~~ usr/local/games"
# ```
#
# 마지막에 `/home/cgb/julia-1.3.1/bin/julia`를 추가한다. 즉 아래와 같이
# 만든다.
#
# ``` default
# ~~ usr/local/games:/home/cgb/julia-1.3.1/bin/julia"
# ```
#
# 세이브하고 나온다. (그런데 이 과정을 안거쳐도 되는것 같음.) 이제
# 커맨드에서 아래를 실행한다.
#
# ``` default
# export PATH=$PATH:/home/cgb/julia-1.3.1/bin
# ```
#
# 이렇게하면 이제 단순히 `julia`라고만 쳐도 `julia`가 실행된다.
#
# # 플루토에서 강의영상 넣는 방법
#
# `-` 아래를 삽입
#
# ``` default
# html"""
# <div style="display: flex; justify-content: center;">
# <div  notthestyle="position: relative; right: 0; top: 0; z-index: 300;">
# <iframe src=
# "
# https://www.youtube.com/embed/
# "
# width=600 height=375  frameborder="0" allow="accelerometer; autoplay; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>
# """
# ```
#
# # 플루토를 이용한 홈페이지 만드는 방법
#
# `-` 단계1: <https://github.com/JuliaPluto/static-export-template> 에
# 가서 `Clone`
#
# `-` 단계2: Setting -\> GitHub Pages -\> Source -\> gh-pages / root
#
# # 플루토 키는 방법
#
# ``` julia
# import Pluto
# Pluto.run(host="0.0.0.0",port=1234,launch_browser=false,require_secret_for_open_links=false,require_secret_for_access=false,threads="8")
# ```
