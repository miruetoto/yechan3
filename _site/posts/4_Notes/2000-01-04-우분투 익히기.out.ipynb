# %% [markdown]
# # **\[Note\]** 우분투 익히기
#
# 신록예찬
# 2000-01-04
#
# # 날짜, 달력
#
# ``` default
# date
# cal
# ```
#
# # 파일시스템
#
# `-` 작업경로, 디렉토리 이동, 파일확인
#
# ``` default
# pwd
# cd cgb2
# cd ~cgb2 ## 어디서든 실행가능
# cd ## cgb2로 로그인 되어있을 경우 cd ~cgb2와 동일
# cd ~cgb2/Dropbox
# ls
# ls -a
# ls -l # 자세히
# ls -lt # 자세히+파일수정시간에 따른 정렬
# ls -lt --reverse # 자세히+파일수정시간의 역순으로 정렬
# ```
#
# `-` 엄밀하게는 `cd cgb2` 는 `cd ./cgb2`로 써야한다. 하지만 `./`는
# 생략가능하므로 그냥 `cd cgb2`라고 쓰는것
#
# `-` 뭐하는 파일인지 알고싶다면?
#
# ``` default
# file picture.jpg
# ```
#
# `-` 카피, 이동, 새폴더, 삭제, 바로가기
#
# ``` default
# cp file1 file2 # file1을 복사하여 file2를 새로 만듬. file2가 이미 있다면 file1의 내용을 덮어씀
# cp file1 file2 -i # 위와 동일한데 덮어쓰기 여부에 대한 확인메시지 생성
# cp file1 file2 --interactive # 위와 동일
# cp -r dir1 dir2 # dir1의 모든파일을 복사하여 dir2로 이동한뒤 붙어넣음. dir2가 없다면 새로 만듬. 기존의 dir2에 있던 파일이 삭제되는건 아님
# cp --recursive dir1 dir2 # 위와 동일
# mv # 카피사용방법과 동일
# mkdir temp
# mkdir temp1, temp2, temp3
# rm file1 # file1삭제
# rm -r file1 dir1 # file1삭제 dir1폴더삭제
# rm -rf file1 dir1 # 위와 동일한데 file1이나 dir1이 존재하지 않더라고 rm이 실행
# ln ## 바로 가기 만드는건데 쓸줄모름 배우기 싫어
# ```
#
# `-` -v(verbose)를 쓰면 친절한 느낌이 든다.
#
# ``` default
# (base) cgb2@cgb2-desktop:~/Dropbox$ cp *.txt temppp -v
# 'colab.txt' -> 'temppp/colab.txt'
# ```
#
# # echo
#
# `-` echo 기본기능
#
# ``` default
# cgb2@cgb2-desktop:~/Dropbox/temppp$ echo test
# test
# ```
#
# `-` echo + `*` : `*`가 현재 디렉토리에 있는 모든 파일이름으로
# 확장된이후에 echo가 동작함.
#
# ``` default
# (base) cgb2@cgb2-desktop:~/Dropbox/temppp$ ls
# colab.txt  sample.txt
# (base) cgb2@cgb2-desktop:~/Dropbox/temppp$ echo *
# colab.txt sample.txt
# ```
#
# `-` 응용
#
# ``` default
# (base) cgb2@cgb2-desktop:~$ echo D*
# Desktop Documents Downloads Dropbox
# ```
#
# `-` 응용2
#
# ``` default
# (base) cgb2@cgb2-desktop:~$ echo /usr/*
# /usr/bin /usr/games /usr/include /usr/lib /usr/lib32 /usr/lib64 /usr/libexec /usr/libx32 /usr/local /usr/sbin /usr/share /usr/src
# ```
#
# `-` 응용3
#
# ``` default
# (base) cgb2@cgb2-desktop:~$ echo ~
# /home/cgb2
# ```
#
# `-` 응용4
#
# ``` default
# (base) cgb2@cgb2-desktop:~/Dropbox$ echo $((2+2))
# 4
# ```
#
# # 기본디렉토리 설명
#
# `/bin` 시스템 부팅과 실행에 필요한 바이너리(프로그램)들을 포함
#
# `/etc` 시스템 전반의 환경설정. 이 디렉터리의 모든 파일은 텍스트형식임.
#
# -   `/etc/password` 사용자 계정정보
#
# `/lib` 시스템 프로그램에서 사용하는 공유 라이브러리가 저장. 윈도우즈의
# DLL과 비슷한 것.
#
# `/usr` 사용자가 사용하는 모든 프로그램과 지원파일들 (Program files +
# 프로그램들의 설정값)
#
# -   `/usr/bin` 리눅스 배포판이 설치한 실행 프로그램들이 있다. (여기에
#     R이 깔린다!!)
#
#     -   hp-align, hp-check, hp-config_usb-printer …
#     -   X11
#     -   vi
#     -   gcc
#     -   su, sudo
#     -   sar
#     -   ssh, ssh-agent, ssh-keygen, ….
#     -   nvidia-smi
#
# -   `/usr/lib` 여기에는 `/usr/bin`에 있는 프로그램들을 위한
#     공유라이브러리가 저장된다. (여기에 R folder가 있다)
#
#     -   여기에 R폴더가 있다. 그런데 R패키지가 여기에 깔리진 않음
#
# -   `/usr/local/bin` 소스코드로 컴파일된 파일, 보통 비어있음
#
# -   `/usr/local/lib/R/site-library` R패키지가 설치되어있음, 예를들면
#     tidyverse
#
# # vim
#
# `-` 파일여는법/만드는법 (sudo는 읽기전용 파일을 만들수있음)
#
# ``` default
# sudo vim /etc/apt/sources.list
# ```
#
# `-` 에디터에서 사용법
#
# ``` default
# i
# ESC
# :w
# :q
# :wq
# /keyword
# dd # 현재행삭제
# ```
#
# # wget
#
# ``` default
# wget https://download2.rstudio.org/server/bionic/amd64/rstudio-server-1.2.5033-amd64.deb
# ```
#
# # gdebi
#
# ``` default
# sudo gdebi rstudio-server-1.2.5033-amd64.deb
# ```
#
# # apt
#
# ``` default
# sudo apt-get remove r-base-core
# sudo apt purge r-base* r-recommended r-cran-*
# sudo apt autoremove
# sudo apt list
# sudo apt update
# sudo apt install openssh-server
# sudo apt-get install gdebi-core
# ```
#
# `-` sudo apt-get과 sudo apt 차이? 별 차이 없는듯 -
# https://askubuntu.com/questions/445384/what-is-the-difference-between-apt-and-apt-get
#
# > They are very similar command line tools available in Trusty (14.04)
# > and later. apt-get and apt-cache’s most commonly used commands are
# > available in apt. apt-get may be considered as lower-level and
# > “back-end”, and support other APT-based tools. apt is designed for
# > end-users (human) and its output may be changed between versions.
#
# # conda
#
# ``` default
# conda
# conda env -h
# conda install -h
# conda remove -h
# conda update -h
# conda env list
# conda create -n py38r40 python=3.8
# conda env remove -n py38r40
# conda install -c conda-forge jupyterlab
# conda remove jupyterlab
# conda remove r-base -y
# conda remove -n py38r40 jupyterlab
# conda update scipy
# conda update -n py38r40 scipy
# conda list
# ```
#
# # pip
#
# ``` default
# pip
# pip list
# pip list > list.txt
# pip freeze # 좀 더 자세히 나온다
# pip freeze > list.txt
# pip show matplotlib # 설치된패키지 정보가 나옴. 좋음.
# pip install rpy2
# pip install -r list.txt
# pip install dash==1.13.3
# pip install jupyterlab "ipywidgets>=7.5"
# pip install -U numpy
# pip install --upgrade pip
# pip install --upgrade tensorflow
# pip uninstall matplotlib
# ```
#
# # 리소스 모니터링
#
# ``` default
# df # disk
# free # memory
# nvidia-smi
# watch -n 5 nvidia-smi -a --display=utilization
# top
# sar -1 r
#
# # 나노에디터
#
# `-` 파일열기
#
# ```default
# sudo nano /etc/apt/sources.list
# ```
#
# `-` 읽기전용 파일만들기: 파일을 만드는것도 파일 여는방법과 동일함. 즉
# 아래와 같이 하면 `exam.txt`가 현재 폴더에 있다면 `열고`아니면
# `(읽기전용으로) 만든다.`
#
# ``` default
# sudo nano /home/cgb/Desktop/exam.txt
# ```
#
# `-` 읽기전용이 아닌 일반파일 만들기
#
# ``` default
# nano /home/cgb/Desktop/exam.txt
# ```
#
# `-` 나노에디터종료: `컨트롤+X`
#
# `-` 파일저장: `컨트롤+O`
#
# `-` 찾기: `컨트롤+W`
#
# `-` 되돌리기: `알트+U`
#
# # ssh
#
# `-` 처음에 ssh를 연결하기위해서는 연결**당하는** 컴퓨터에 가서 아래를
# 실행해야 한다.
#
# ``` default
# sudo apt install openssh-server
# ```
#
# #### 22번포트 우회하기
#
# `-` step1: `/etc/ssh/sshd_config` 파일을 연다.
#
# ``` default
# sudo vi /etc/ssh/sshd_config
# ```
#
# `-` step2: Port 22 라고 된 부분의 주석을 풀고 원하는 포트번호 설정
#
# ``` default
# ...
#
# #Port 22
# #AddressFamily any
# #ListenAddress 0.0.0.0
# #ListenAddress ::
#
# ...
# ```
#
# `-` step3: 수정내용을 적용
#
# ``` default
# sudo systemctl restart ssh.service
# ```
#
# `-` step4: 수정한 포트로 ssh접속
#
# # sublime
#
# `-` 찾아바꾸기: 컨트롤+h
#
# `-` 화면분할: 옵션+커맨드+2,3,4 …
#
# # 파일생성, 파일삭제
#
# ``` default
# cat > sample.txt
# rm -r folderName
# rm -rf .local/share/Trash/files/* # 휴지통삭제
# ```
#
# # deb
#
# ``` default
# dpkg -i quarto-1.2.335-linux-amd64.deb # 설치
# dpkg -r quarto # 삭제
# ```
